# %%
from vedo import *
import numpy as np

# %%
x = np.arange(0, 1000, 0.1)
y = np.sin(x)

line = Line(x,y)
pointcloud = load('C:/Users/ali49/erl_python_simulation/erl_python_simulation/PointCloud/testingpointcloud.ply')

# %%
rgb = load('C:/Users/ali49/erl_python_simulation/erl_python_simulation/PointCloud/rgb.png')
show(pointcloud, rgb, line, interactive = True)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600>
